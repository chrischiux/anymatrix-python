# %%
from anymatrix import Anymatrix
import numpy as np
import matlab.engine
import itertools
am = Anymatrix()
am.test_anymatrix_properties()
# Out:
# Warning: Property symmetric in core/beta is not recognized.
# Warning: Property positive definite in core/beta is not recognized.
# Warning: Property integer in core/beta is not recognized.
# Warning: Property totally positive in core/beta is not recognized.
# Warning: Property infinitely divisible in core/beta is not recognized.
# Warning: Property built-in in core/beta is not recognized.
# Warning: Property real in core/beta is not recognized.
# Warning: Property scalable in core/beta is not recognized.
# Warning: Property square in core/beta is not recognized.
# Warning: Property positive in core/beta is not recognized.
# Warning: Property nonnegative in core/beta is not recognized.
# Warning: Property totally nonnegative in core/beta is not recognized.
# Warning: Property built-in in matlab/compan is not recognized.
# Warning: Property real in matlab/compan is not recognized.
# Warning: Property scalable in matlab/compan is not recognized.
# Warning: Property square in matlab/compan is not recognized.
# Warning: Property square in matlab/hadamard is not recognized.
# Warning: Property fixed size in matlab/hadamard is not recognized.
# Warning: Property integer in matlab/hadamard is not recognized.
# Warning: Property built-in in matlab/hadamard is not recognized.
# Warning: Property real in matlab/hadamard is not recognized.
# Warning: Property hankel in matlab/hankel is not recognized.
# Warning: Property built-in in matlab/hankel is not recognized.
# Warning: Property real in matlab/hankel is not recognized.
# Warning: Property scalable in matlab/hankel is not recognized.
# Warning: Property square in matlab/hankel is not recognized.
# Warning: Property symmetric in matlab/hankel is not recognized.
# Warning: Property symmetric in matlab/hilb is not recognized.
# Warning: Property positive definite in matlab/hilb is not recognized.
# Warning: Property totally positive in matlab/hilb is not recognized.
# Warning: Property inverse in matlab/hilb is not recognized.
# Warning: Property ill conditioned in matlab/hilb is not recognized.
# Warning: Property built-in in matlab/hilb is not recognized.
# Warning: Property real in matlab/hilb is not recognized.
# Warning: Property scalable in matlab/hilb is not recognized.
# Warning: Property square in matlab/hilb is not recognized.
# Warning: Property positive in matlab/hilb is not recognized.
# Warning: Property nonnegative in matlab/hilb is not recognized.
# Warning: Property totally nonnegative in matlab/hilb is not recognized.
# Warning: Property symmetric in matlab/invhilb is not recognized.
# Warning: Property positive definite in matlab/invhilb is not recognized.
# Warning: Property inverse in matlab/invhilb is not recognized.
# Warning: Property ill conditioned in matlab/invhilb is not recognized.
# Warning: Property built-in in matlab/invhilb is not recognized.
# Warning: Property real in matlab/invhilb is not recognized.
# Warning: Property scalable in matlab/invhilb is not recognized.
# Warning: Property square in matlab/invhilb is not recognized.
# Warning: Property integer in matlab/magic is not recognized.
# Warning: Property positive in matlab/magic is not recognized.
# Warning: Property built-in in matlab/magic is not recognized.
# Warning: Property real in matlab/magic is not recognized.
# Warning: Property scalable in matlab/magic is not recognized.
# Warning: Property square in matlab/magic is not recognized.
# Warning: Property nonnegative in matlab/magic is not recognized.
# Warning: Property symmetric in matlab/pascal is not recognized.
# Warning: Property positive definite in matlab/pascal is not recognized.
# Warning: Property integer in matlab/pascal is not recognized.
# Warning: Property involutory in matlab/pascal is not recognized.
# Warning: Property totally positive in matlab/pascal is not recognized.
# Warning: Property ill conditioned in matlab/pascal is not recognized.
# Warning: Property built-in in matlab/pascal is not recognized.
# Warning: Property real in matlab/pascal is not recognized.
# Warning: Property scalable in matlab/pascal is not recognized.
# Warning: Property square in matlab/pascal is not recognized.
# Warning: Property positive in matlab/pascal is not recognized.
# Warning: Property nonnegative in matlab/pascal is not recognized.
# Warning: Property totally nonnegative in matlab/pascal is not recognized.
# Warning: Property fixed size in matlab/rosser is not recognized.
# Warning: Property symmetric in matlab/rosser is not recognized.
# Warning: Property indefinite in matlab/rosser is not recognized.
# Warning: Property integer in matlab/rosser is not recognized.
# Warning: Property rank deficient in matlab/rosser is not recognized.
# Warning: Property built-in in matlab/rosser is not recognized.
# Warning: Property real in matlab/rosser is not recognized.
# Warning: Property square in matlab/rosser is not recognized.
# Warning: Property integer in matlab/spiral is not recognized.
# Warning: Property positive in matlab/spiral is not recognized.
# Warning: Property built-in in matlab/spiral is not recognized.
# Warning: Property real in matlab/spiral is not recognized.
# Warning: Property scalable in matlab/spiral is not recognized.
# Warning: Property square in matlab/spiral is not recognized.
# Warning: Property nonnegative in matlab/spiral is not recognized.
# Warning: Property toeplitz in matlab/toeplitz is not recognized.
# Warning: Property square in matlab/toeplitz is not recognized.
# Warning: Property rectangular in matlab/toeplitz is not recognized.
# Warning: Property built-in in matlab/toeplitz is not recognized.
# Warning: Property real in matlab/toeplitz is not recognized.
# Warning: Property scalable in matlab/toeplitz is not recognized.
# Warning: Property built-in in matlab/vander is not recognized.
# Warning: Property real in matlab/vander is not recognized.
# Warning: Property scalable in matlab/vander is not recognized.
# Warning: Property square in matlab/vander is not recognized.
# Warning: Property symmetric in matlab/wilkinson is not recognized.
# Warning: Property indefinite in matlab/wilkinson is not recognized.
# Warning: Property tridiagonal in matlab/wilkinson is not recognized.
# Warning: Property nonnegative in matlab/wilkinson is not recognized.
# Warning: Property built-in in matlab/wilkinson is not recognized.
# Warning: Property real in matlab/wilkinson is not recognized.
# Warning: Property scalable in matlab/wilkinson is not recognized.
# Warning: Property square in matlab/wilkinson is not recognized.
# Warning: Property banded in matlab/wilkinson is not recognized.
# ============================= test session starts =============================
# platform win32 -- Python 3.12.9, pytest-8.3.5, pluggy-1.5.0
# rootdir: C:\Users\Chris\Documents\VS Code\Year 3\anymatrix\anymatrix-python
# plugins: anyio-4.8.0, xdist-3.6.1
# collected 93 items
#
# anymatrix\testing\anymatrix_func_based_tests.py ........................ [ 25%]
# .....................................................................    [100%]
#
# ============================= 93 passed in 1.61s ==============================

# %%
import timeit


print(timeit.repeat('am.anymatrix("sets","test_set")', globals=globals(), number=100, repeat=1)[0]/100)

# %%
print(timeit.repeat('am.anymatrix("prop","integer and positive")', globals=globals(), number=5000, repeat=1)[0]/5000)

# %%
eng = matlab.engine.start_matlab()
eng.cd(r"C:\Users\propo\OneDrive - University of Leeds\Documents\MATLAB\anymatrix", nargout=1)
# Out:
# 'C:\\Users\\propo\\OneDrive - University of Leeds\\Documents\\VS Code\\Level3\\project'

# %%
matrix_ID = ["core/beta"]
matrix_size = [2000]
comb = list(itertools.product(matrix_ID, matrix_size))

for args in comb:
    python_result = am.anymatrix(args[0], args[1])
    matlab_result = eng.anymatrix(args[0], float(args[1]))
    converted = np.array(matlab_result)
    result = np.array_equal(python_result, converted)
    print(args, result)
    
    if result == True:
        continue
    
    # for i in range(args[1]):
    #         for j in range(args[1]):
    #             if python_result[i,j] != converted[i,j]:
    #                 print(i,j, python_result[i,j], converted[i,j])
# Out:
# c:\Users\propo\OneDrive - University of Leeds\Documents\VS Code\Level3\project\anymatrix\core\private\beta.py:35: RuntimeWarning: overflow encountered in scalar multiply
#   R[i-1, j-1] = comb(j-1, i-1) * sqrt(i - 1)
# ('core/beta', 2000) True

# %%
am.anymatrix("prop", "square and rectangular and scalable")
# Out:
# ['matlab/toeplitz']

# %%
am.anymatrix("prop", "matlab/toeplitz")
# Out:
# ['toeplitz', 'square', 'rectangular', 'built-in', 'real', 'scalable']

# %%
type(4/2)
# Out:
# float
